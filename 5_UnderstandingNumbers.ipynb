# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/Python_Basics/blob/main/5_UnderstandingNumbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## integer 정수 (10진수), binary (2진수), octal (8진수), hexadecimal (16진수)
#
# - Useful information:
#
#   i) 일반적으로 컴퓨터에 기록되는 데이터의 최소 단위는 8비트 또는 1비트이다. 1 비트는 한자리 2 진수이기 때문에 8비트는 8자리 2진수로 표현된다.
#
#   ii) 8진수는 3자리 2진수로 표현 가능
#
#   iii) 16진수는 4자리 2진수로 표현 가능
#
#       따라서 1비트 데이터는 두자리 16진수로 표현 가능하기 때문에 컴퓨터에 기록된 대부분의 데이터는 16진수로 표현이 가능하다????????
#
# - Converting interger to binary, octal, bexadecimal numbers with Python: 변환값은 문자열 (0b, 0o, 0x)이 된다.
#
#   i) bin(value)
#
#   ii) oct(value)
#
#   iii) hex(value)

# %%
value = 100

a=bin(value)
print(a)

b=oct(value)
print(b)

c=hex(value)
print(c)

# %% [markdown]
# ## ✅ 실수형 상수 자료
# - 유리수: 소수로 나타낼 수 있는 수
# - 무리수: 원주율이나 root2 와 가은 소수로 표현할 수 없는 무리수
# - 파이썬에서 소수점으로 나타내는 상수는 실수형 상수로 간주
#       실수형 상수를 표현하는 다른 방법
#
#       - e: 10의 거듭제곱
#       e.g., e2 = 10의 2승, e-3 = 10의 -3승, 1.56e3 = 1.56X10의 3승 (=1560.0), -0.7e-4 = 7e-5

# %%
f1=1.0
print(f1)

f2=3.14
print(f2)

f3=1.56e3
print(f3)

f4=0.7e-4
print(f4)

# %% [markdown]
# ## ✅ 복소수형 상수 자료
# - 실수부 + 허수부 (j)
#
#   - 복소수형 자료에서 실수부만 취할 때는 real
#   - 복소수형 자료에서 허수부만 취할 때는 imag
#
#         e.g., 1+7j
#
#         real  ➡️ 1.0
#         imag  ➡️ 7.0
#
# - complex()를 이용하여 복소수형 상수를 구성한다.
#
#   - complex(2,3) 에서 real실수부  ➡️ 2, imag허수부  ➡️ 3
#
#         complex(2,3)
#         2+3j

# %%
c1=1+7j
print(c1.real); print(c1.imag)

c2=complex(2,3)
print(c2)
