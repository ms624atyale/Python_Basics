# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/Python_Basics/blob/main/LexicalDiversity_Aesop4Children_LexicalDiversitywithLD_TextstatLibrary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ms624atyale/Data_Class

# %%
# %cd /content/Data_Class/PG Aesop NoQuotes

# %% [markdown]
# ### <font color = 'pink'> 🔋 🔌 **Now** move "PG Aesop NoQuotes' file under [PG Aesop NoQuotes folder] **to** [the sample_data folder]!

# %%
file = open("/content/sample_data/txtdata_only.txt", 'rt')
txt = file.read()
print(txt)
file.close() #Using this close()function, you are no longer using your text file of the current workingdirectory with open()function.

# %%
# !pip install nltk
import nltk
nltk.download('punkt')

# %%
from nltk.tokenize import sent_tokenize
sentence = sent_tokenize(txt)
print('Sentence Tokenized: %s' %sentence)

# %% [markdown]
# New Session

# %%
file = open("/content/sample_data/txtdata_only.txt", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

# %% [markdown]
# ###**<font color = 'red'>Gneral Information**
# Function.	Type	symbols or words	result	example
# RegexpTokenizer()	punctuation	".", ",", "?", "!", ";", ":"	deleted
# apostrophe	"'"	deleted
# word-linking hyphen	"-"	deleted
# phrase-linking hyphen	"--"	deleted
# Capital vs. small	The ones	tokenize	'The', 'ones'
# they're, were having		'they', 're', 'were', 'hav'

# %% [markdown]
# 💡 🔎 **RegexpTokenizer** is a <font color = 'red'>_class_</font>.
# - An example code line:
#   - **from nltk.tokenize import RegexpTokenizer**
#
# - It is part of the nltk.tokenize module and is used for tokenizing text based on regular expression patterns. When you import RegexpTokenizer using this line, you make the RegexpTokenizer class available for use in your Python script or program. You can create instances of this class to tokenize text based on specific regular expression patterns.

# %%
# 💡💣 Example of Type Error

file = open("/content/sample_data/txtdata_only.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer()
# If you leave RegexpTokenizer() as it is;
# "TypeError: RegexpTokenizer.init() missing 1 required positional argument: 'pattern'", indicates that when initializing the RegexpTokenizer class,
# you didn't provide the required regular expression pattern as an argument.
# The RegexpTokenizer constructor expects a regular expression pattern as a string.
# You should provide a valid pattern that defines how you want to tokenize the text.

result = retokenize.tokenize(obj)
print('Tokenizing Words with RegexpTokenizer: %s' %result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-0bd8248e20c8> in <cell line: 7>()
#       5 from nltk.tokenize import RegexpTokenizer
#       6
# ----> 7 retokenize = RegexpTokenizer()
#       8 # If you leave RegexpTokenizer() as it is;
#       9 # "TypeError: RegexpTokenizer.init() missing 1 required positional argument: 'pattern'", indicates that when initializing the RegexpTokenizer class,
#
# TypeError: RegexpTokenizer.__init__() missing 1 required positional argument: 'pattern'

# %%
#💊 📎 You need to provide the required regular expression pattern as an argument when initializing the RegexpTokenizer Class
file = open("/content/sample_data/txtdata_only.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

#A regular expression pattern is defined within the RegexpTokenizer constructor: [\w]+. This pattern is used for tokenization.
retokenize = RegexpTokenizer("[\w]+")
# This codeline is designed to match one or more consecutive word characters.
# In the context of regular expressions, \w typically represents a word character (alphanumeric character, including letters and digits),
# and + indicates that one or more such characters should be matched.
# Alert: You cannot use RegexpTokenizer() without argument. You need 'pattern.'
# Look up __

result = retokenize.tokenize(obj)
#tokenize the text data stored in the obj variable using the specified regular expression pattern.

print('Tokenizing Words with RegexpTokenizer: %s' %result)
# Out:
# Tokenizing Words with RegexpTokenizer: ['THE', 'WOLF', 'AND', 'THE', 'KID', 'There', 'was', 'once', 'a', 'little', 'Kid', 'whose', 'growing', 'horns', 'made', 'him', 'think', 'he', 'was', 'a', 'grown', 'up', 'Billy', 'Goat', 'and', 'able', 'to', 'take', 'care', 'of', 'himself', 'So', 'one', 'evening', 'when', 'the', 'flock', 'started', 'home', 'from', 'the', 'pasture', 'and', 'his', 'mother', 'called', 'the', 'Kid', 'paid', 'no', 'heed', 'and', 'kept', 'right', 'on', 'nibbling', 'the', 'tender', 'grass', 'A', 'little', 'later', 'when', 'he', 'lifted', 'his', 'head', 'the', 'flock', 'was', 'gone', 'He', 'was', 'all', 'alone', 'The', 'sun', 'was', 'sinking', 'Long', 'shadows', 'came', 'creeping', 'over', 'the', 'ground', 'A', 'chilly', 'little', 'wind', 'came', 'creeping', 'with', 'them', 'making', 'scary', 'noises', 'in', 'the', 'grass', 'The', 'Kid', 'shivered', 'as', 'he', 'thought', 'of', 'the', 'terrible', 'Wolf', 'Then', 'he', 'started', 'wildly', 'over', 'the', 'field', 'bleatin
# ...

# %%
#💊 📎 💡 How to write the require regular expression pattern as an argument II

file = open("/content/sample_data/txtdata_only.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

#A regular expression pattern is defined within the RegexpTokenizer constructor: [\w]+. This pattern is used for tokenization.
pattern = r'\w+'

retokenize = RegexpTokenizer(pattern)
# This codeline is designed to match one or more consecutive word characters.
# In the context of regular expressions, \w typically represents a word character (alphanumeric character, including letters and digits),
# and + indicates that one or more such characters should be matched.
# Alert: You cannot use RegexpTokenizer() without argument. You need 'pattern.'
# Look up __

result = retokenize.tokenize(obj)
#tokenize the text data stored in the obj variable using the specified regular expression pattern.

print('Tokenizing Words with RegexpTokenizer: %s' %result)
# Out:
# Tokenizing Words with RegexpTokenizer: ['THE', 'WOLF', 'AND', 'THE', 'KID', 'There', 'was', 'once', 'a', 'little', 'Kid', 'whose', 'growing', 'horns', 'made', 'him', 'think', 'he', 'was', 'a', 'grown', 'up', 'Billy', 'Goat', 'and', 'able', 'to', 'take', 'care', 'of', 'himself', 'So', 'one', 'evening', 'when', 'the', 'flock', 'started', 'home', 'from', 'the', 'pasture', 'and', 'his', 'mother', 'called', 'the', 'Kid', 'paid', 'no', 'heed', 'and', 'kept', 'right', 'on', 'nibbling', 'the', 'tender', 'grass', 'A', 'little', 'later', 'when', 'he', 'lifted', 'his', 'head', 'the', 'flock', 'was', 'gone', 'He', 'was', 'all', 'alone', 'The', 'sun', 'was', 'sinking', 'Long', 'shadows', 'came', 'creeping', 'over', 'the', 'ground', 'A', 'chilly', 'little', 'wind', 'came', 'creeping', 'with', 'them', 'making', 'scary', 'noises', 'in', 'the', 'grass', 'The', 'Kid', 'shivered', 'as', 'he', 'thought', 'of', 'the', 'terrible', 'Wolf', 'Then', 'he', 'started', 'wildly', 'over', 'the', 'field', 'bleatin
# ...

# %% [markdown]
# 💣 <font color = 'red'>I need to understand ChatGPT's explanation in the following:
#
# In regular expressions, square brackets [ ] are used to create character classes, which define a set of characters that you want to match. The usage of square brackets depends on the context and what you want to achieve in your regular expression.
#
# In the two code lines you provided:
#
# (1) retokenize = RegexpTokenizer("[\w]+")
#
# Here, you are using square brackets to create a character class that matches one or more word characters (\w). In this case, you are explicitly defining a character class within the regular expression.
#
# (2) pattern = r'\w+'; retokenize = RegexpTokenizer(pattern)
#
# In the second code line, you define the regular expression pattern separately as r'\w+', and then you pass this pattern as a string to the RegexpTokenizer constructor. The RegexpTokenizer class is designed to accept a string pattern as an argument, so you don't need to use square brackets in this specific line because the pattern is already defined as a string.
#
# In both cases, you achieve the same result: tokenizing text based on one or more word characters. The difference is in how you specify the pattern. In the first case, you define the pattern within the constructor and use square brackets to create a character class. In the second case, you define the pattern as a string separately and then pass it to the constructor. The second approach is often preferred when you want to reuse the pattern or make the code more readable.

# %%
import re
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/sample_data/txtdata_only.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content
tok = ld.tokenize(file_content)
print(tok)

#file = open("/content/sample_data/NoQuotesAllText.txt", 'rt')
#file.read()
#tok = ld.tokenize(file)
# Out:
# ...
# ['the', 'wolf', 'and', 'the', 'kid', 'there', 'was', 'once', 'a', 'little', 'kid', 'whose', 'growing', 'horns', 'made', 'him', 'think', 'he', 'was', 'a', 'grownup', 'billy', 'goat', 'and', 'able', 'to', 'take', 'care', 'of', 'himself', 'so', 'one', 'evening', 'when', 'the', 'flock', 'started', 'home', 'from', 'the', 'pasture', 'and', 'his', 'mother', 'called', 'the', 'kid', 'paid', 'no', 'heed', 'and', 'kept', 'right', 'on', 'nibbling', 'the', 'tender', 'grass', 'a', 'little', 'later', 'when', 'he', 'lifted', 'his', 'head', 'the', 'flock', 'was', 'gone', 'he', 'was', 'all', 'alone', 'the', 'sun', 'was', 'sinking', 'long', 'shadows', 'came', 'creeping', 'over', 'the', 'ground', 'a', 'chilly', 'little', 'wind', 'came', 'creeping', 'with', 'them', 'making', 'scary', 'noises', 'in', 'the', 'grass', 'the', 'kid', 'shivered', 'as', 'he', 'thought', 'of', 'the', 'terrible', 'wolf', 'then', 'he', 'started', 'wildly', 'over', 'the', 'field', 'bleating', 'for', 'his', 'mother', 'but', 'not', '
# ...

# %%
#Alternative to the pevious code cell [#21]
#TRY TO RUN AFTER GETTING THE FOLLOWING THREE CODELINES ACTIVATED!!!
#count = len(tok)
#print(count)
#print(tok[:26367])
# Out:
# 26368
# ...

# %%
flt = ld.flemmatize(file_content)

# %%
print(ld.ttr(flt))
# Out:
# 0.10759253640776699

# %% [markdown]
# Consider including eliminating stopwords if you can come up with something decent cause.
# - shortword = re.compile(r'\W*\b\w{1,3}\b') #Remove words less than 3 letters.

# %% [markdown]
# 🔌 After getting reviewers' comments on sttr.

# %%
# !pip install textstat  # Install the textstat library

from nltk.tokenize import RegexpTokenizer
from textstat import textstat  # Import the textstat library

# Tokenize the text using RegexpTokenizer
file_path = "/content/sample_data/txtdata_only_lexicaldiversity.txt"

retokenize = RegexpTokenizer(r"[\w]+")

with open(file_path, 'rt') as file:
    file_content = file.read()

tokens = retokenize.tokenize(file_content)

# Calculate the STTR
sttr = textstat.STTR(tokens)
print("STTR (Standardized Type-Token Ratio):", sttr)
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0b43010463fc> in <cell line: 17>()
#      15
#      16 # Calculate the STTR
# ---> 17 sttr = textstat.STTR(tokens)
#      18 print("STTR (Standardized Type-Token Ratio):", sttr)
#
# AttributeError: 'textstatistics' object has no attribute 'STTR'

# %% [markdown]
# 🔌 [chatGPT) I apologize for the confusion. It seems there is an issue with the textstat library, and it doesn't provide the STTR attribute. To calculate the standardized type-token ratio (STTR), you can use a different approach without relying on the textstat library.
#
# Here's an alternative method to calculate the STTR:

# %%
from nltk.tokenize import RegexpTokenizer

# Tokenize the text using RegexpTokenizer
file_path = "/content/sample_data/txtdata_only_lexicaldiversity.txt"

retokenize = RegexpTokenizer(r"[\w]+")

with open(file_path, 'rt') as file:
    file_content = file.read()

tokens = retokenize.tokenize(file_content)

# Calculate the STTR
unique_tokens = set(tokens)
num_unique_tokens = len(unique_tokens)
total_tokens = len(tokens)

sttr = num_unique_tokens / total_tokens
print("STTR (Standardized Type-Token Ratio):", sttr)
# Out:
# STTR (Standardized Type-Token Ratio): 0.13840739770132154

# %%
from nltk.tokenize import RegexpTokenizer
import math

# Tokenize the text using RegexpTokenizer
file_path = "/content/sample_data/txtdata_only_lexicaldiversity.txt"

retokenize = RegexpTokenizer(r"[\w]+")

with open(file_path, 'rt') as file:
    file_content = file.read()

tokens = retokenize.tokenize(file_content)

# Calculate the STTR
unique_tokens = set(tokens)
num_unique_tokens = len(unique_tokens)
total_tokens = len(tokens)

sttr = num_unique_tokens / math.sqrt(total_tokens)  # Apply square root to the denominator
print("STTR (Standardized Type-Token Ratio):", sttr)
# Out:
# STTR (Standardized Type-Token Ratio): 22.62061337147571

# %%
import math

# Load your text data
with open("/content/sample_data/txtdata_only_lexicaldiversity.txt", "r") as file:  # Replace with the path to your text file
    text = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or a custom tokenizer)
words = text.split()  # Simple word splitting for this example

# Calculate the number of unique tokens and total tokens
unique_tokens = set(words)
num_unique_tokens = len(unique_tokens)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# STTR (Standardized Type-Token Ratio): 0.45187900729723973

# %%
from collections import Counter
import math

# Load your text data
with open("/content/sample_data/txtdata_only_lexicaldiversity.txt", "r") as file:  # Replace with the path to your text file
    text = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or a custom tokenizer)
words = text.split()  # Simple word splitting for this example

# Calculate the number of unique tokens and total tokens
word_counts = Counter(words)
num_unique_tokens = len(word_counts)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# STTR (Standardized Type-Token Ratio): 0.45187900729723973

# %%
import math

# Sample text (replace with your own text)
#sample_text = "This is a sample text for calculating STTR. It contains several unique words and tokens."

# Load your text data
with open("/content/sample_data/txtdata_only_lexicaldiversity.txt", "r") as file:  # Replace with the path to your text file
    sample_text = file.read()

# Tokenize the sample text into words
words = sample_text.split()  # You can use more advanced tokenization methods if needed

# Calculate the number of unique tokens and total tokens
unique_tokens = set(words)
num_unique_tokens = len(unique_tokens)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# STTR (Standardized Type-Token Ratio): 0.45187900729723973

# %% [markdown]
# 🔌 The below is the original script for ttr used in the 1st draft of the paper. Then split it into 7 arbitrary parts.

# %% [markdown]
# #**<font color = 'red'>147 episodes for Aesop for Children**

# %%
file = open("/content/sample_data/txtdata_only_lexicaldiversity.txt", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

file = open("/content/sample_data/txtdata_only_lexicaldiversity.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

print('Tokenizing Words with RegexpTokenizer: %s' %result); import re
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/sample_data/txtdata_only_lexicaldiversity.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content and TTR
tok = ld.tokenize(file_content)
print(tok)
flt = ld.flemmatize(file_content); print(ld.ttr(flt))

#STTR
from collections import Counter
import math

# Load your text data
with open("/content/sample_data/txtdata_only_lexicaldiversity.txt", "r") as file:  # Replace with the path to your text file
    text = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or a custom tokenizer)
words = text.split()  # Simple word splitting for this example

# Calculate the number of unique tokens and total tokens
word_counts = Counter(words)
num_unique_tokens = len(word_counts)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# count word tokens: 26711
# ...

# %% [markdown]
# Part1 of Aesop

# %%
# Word Count, TTR, STTR for Part1 of Aesop for Children

file = open("/content/sample_data/Aesop_7/Part1.txt", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

file = open("/content/sample_data/Aesop_7/Part1.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

print('Tokenizing Words with RegexpTokenizer: %s' %result); import re
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/sample_data/Aesop_7/Part1.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content and TTR
tok = ld.tokenize(file_content)
print(tok)
flt = ld.flemmatize(file_content); print(ld.ttr(flt))

#STTR
from collections import Counter
import math

# Load your text data
with open("/content/sample_data/Aesop_7/Part1.txt", "r") as file:  # Replace with the path to your text file
    text = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or a custom tokenizer)
words = text.split()  # Simple word splitting for this example

# Calculate the number of unique tokens and total tokens
word_counts = Counter(words)
num_unique_tokens = len(word_counts)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# count word tokens: 4050
# ...

# %% [markdown]
# Part2 of Aesop

# %%
# Word Count, TTR, STTR for Part1 of Aesop for Children

file = open("/content/sample_data/Aesop_7/Part2.txt", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

file = open("/content/sample_data/Aesop_7/Part2.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

print('Tokenizing Words with RegexpTokenizer: %s' %result); import re
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/sample_data/Aesop_7/Part2.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content and TTR
tok = ld.tokenize(file_content)
print(tok)
flt = ld.flemmatize(file_content); print(ld.ttr(flt))

#STTR
from collections import Counter
import math

# Load your text data
with open("/content/sample_data/Aesop_7/Part2.txt", "r") as file:  # Replace with the path to your text file
    text = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or a custom tokenizer)
words = text.split()  # Simple word splitting for this example

# Calculate the number of unique tokens and total tokens
word_counts = Counter(words)
num_unique_tokens = len(word_counts)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# count word tokens: 3653
# ...

# %% [markdown]
# Part3 of Aesop

# %%
# Word Count, TTR, STTR for Part1 of Aesop for Children

file = open("/content/sample_data/Aesop_7/Part3.txt", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

file = open("/content/sample_data/Aesop_7/Part3.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

print('Tokenizing Words with RegexpTokenizer: %s' %result); import re
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/sample_data/Aesop_7/Part3.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content and TTR
tok = ld.tokenize(file_content)
print(tok)
flt = ld.flemmatize(file_content); print(ld.ttr(flt))

#STTR
from collections import Counter
import math

# Load your text data
with open("/content/sample_data/Aesop_7/Part3.txt", "r") as file:  # Replace with the path to your text file
    text = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or a custom tokenizer)
words = text.split()  # Simple word splitting for this example

# Calculate the number of unique tokens and total tokens
word_counts = Counter(words)
num_unique_tokens = len(word_counts)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# count word tokens: 3680
# ...

# %% [markdown]
# Part4 of Aesop

# %%
# Word Count, TTR, STTR for Part1 of Aesop for Children

file = open("/content/sample_data/Aesop_7/Part4.txt", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

file = open("/content/sample_data/Aesop_7/Part4.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

print('Tokenizing Words with RegexpTokenizer: %s' %result); import re
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/sample_data/Aesop_7/Part4.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content and TTR
tok = ld.tokenize(file_content)
print(tok)
flt = ld.flemmatize(file_content); print(ld.ttr(flt))

#STTR
from collections import Counter
import math

# Load your text data
with open("/content/sample_data/Aesop_7/Part4.txt", "r") as file:  # Replace with the path to your text file
    text = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or a custom tokenizer)
words = text.split()  # Simple word splitting for this example

# Calculate the number of unique tokens and total tokens
word_counts = Counter(words)
num_unique_tokens = len(word_counts)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# count word tokens: 3570
# ...

# %% [markdown]
# Part5 of Aesop

# %%
# Word Count, TTR, STTR for Part1 of Aesop for Children

file = open("/content/sample_data/Aesop_7/Part5.txt", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

file = open("/content/sample_data/Aesop_7/Part5.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

print('Tokenizing Words with RegexpTokenizer: %s' %result); import re
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/sample_data/Aesop_7/Part5.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content and TTR
tok = ld.tokenize(file_content)
print(tok)
flt = ld.flemmatize(file_content); print(ld.ttr(flt))

#STTR
from collections import Counter
import math

# Load your text data
with open("/content/sample_data/Aesop_7/Part5.txt", "r") as file:  # Replace with the path to your text file
    text = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or a custom tokenizer)
words = text.split()  # Simple word splitting for this example

# Calculate the number of unique tokens and total tokens
word_counts = Counter(words)
num_unique_tokens = len(word_counts)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# count word tokens: 3895
# ...

# %% [markdown]
# Part6 of Aesop

# %%
# Word Count, TTR, STTR for Part1 of Aesop for Children

file = open("/content/sample_data/Aesop_7/Part6.txt", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

file = open("/content/sample_data/Aesop_7/Part6.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

print('Tokenizing Words with RegexpTokenizer: %s' %result); import re
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/sample_data/Aesop_7/Part6.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content and TTR
tok = ld.tokenize(file_content)
print(tok)
flt = ld.flemmatize(file_content); print(ld.ttr(flt))

#STTR
from collections import Counter
import math

# Load your text data
with open("/content/sample_data/Aesop_7/Part6.txt", "r") as file:  # Replace with the path to your text file
    text = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or a custom tokenizer)
words = text.split()  # Simple word splitting for this example

# Calculate the number of unique tokens and total tokens
word_counts = Counter(words)
num_unique_tokens = len(word_counts)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# count word tokens: 3728
# ...

# %% [markdown]
# Part7 of Aesop

# %%
# Word Count, TTR, STTR for Part1 of Aesop for Children

file = open("/content/sample_data/Aesop_7/Part7.txt", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

file = open("/content/sample_data/Aesop_7/Part7.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

print('Tokenizing Words with RegexpTokenizer: %s' %result); import re
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/sample_data/Aesop_7/Part7.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content and TTR
tok = ld.tokenize(file_content)
print(tok)
flt = ld.flemmatize(file_content); print(ld.ttr(flt))

#STTR
from collections import Counter
import math

# Load your text data
with open("/content/sample_data/Aesop_7/Part7.txt", "r") as file:  # Replace with the path to your text file
    text = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or a custom tokenizer)
words = text.split()  # Simple word splitting for this example

# Calculate the number of unique tokens and total tokens
word_counts = Counter(words)
num_unique_tokens = len(word_counts)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# count word tokens: 4135
# ...

# %%
# Word Count, TTR, STTR for Part1 of Aesop for Children

file = open("/content/sample_data/Aesop_7/Part7.txt", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

file = open("/content/sample_data/Aesop_7/Part7.txt", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

print('Tokenizing Words with RegexpTokenizer: %s' %result); import re


import pandas as pd
import textstat

# Define the URL for the text data
url = 'https://github.com/ms624atyale/Data_Class/raw/main/PG%20Aesop%20Lexical%20Diversity/txtdata_only_lexicaldiversity.txt'

# Read the text data from the URL
df = pd.read_csv(url, header=None, names=['Text'], sep='\n')

# Extract the text from the DataFrame
text_data = df['Text'].str.cat(sep=' ')

# Tokenize the text into words (you can use NLTK, spaCy, or other tokenizers)
words = text_data.split()

# Define the window size for MSTTR
window_size = 500

# Calculate MSTTR using the textstat library
msttr_values = textstat.msttr(words, window_size)

# Print the MSTTR values
print("MSTTR (Moving Standardized Type-Token Ratio) values:")
print(msttr_values)

# %%
import pandas as pd
import textstat

with open("/content/sample_data/txtdata_only_lexicaldiversity.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content and TTR
tok = ld.tokenize(file_content)
print(tok)
flt = ld.flemmatize(file_content); print(ld.ttr(flt))

# Read the text content from the file
with open("/content/sample_data/txtdata_only_lexicaldiversity.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or other tokenizers)
words = file_content.split()

# Define the window size for MSTTR
window_size = 500

# Calculate MSTTR using the textstat library
msttr_values = textstat.msttr(words, window_size)

# Print the MSTTR values
print("MSTTR (Moving Standardized Type-Token Ratio) values:")
print(msttr_values)
# Out:
# ['the', 'wolf', 'and', 'the', 'kid', 'there', 'was', 'once', 'a', 'little', 'kid', 'whose', 'growing', 'horns', 'made', 'him', 'think', 'he', 'was', 'a', 'grownup', 'billy', 'goat', 'and', 'able', 'to', 'take', 'care', 'of', 'himself', 'so', 'one', 'evening', 'when', 'the', 'flock', 'started', 'home', 'from', 'the', 'pasture', 'and', 'his', 'mother', 'called', 'the', 'kid', 'paid', 'no', 'heed', 'and', 'kept', 'right', 'on', 'nibbling', 'the', 'tender', 'grass', 'a', 'little', 'later', 'when', 'he', 'lifted', 'his', 'head', 'the', 'flock', 'was', 'gone', 'he', 'was', 'all', 'alone', 'the', 'sun', 'was', 'sinking', 'long', 'shadows', 'came', 'creeping', 'over', 'the', 'ground', 'a', 'chilly', 'little', 'wind', 'came', 'creeping', 'with', 'them', 'making', 'scary', 'noises', 'in', 'the', 'grass', 'the', 'kid', 'shivered', 'as', 'he', 'thought', 'of', 'the', 'terrible', 'wolf', 'then', 'he', 'started', 'wildly', 'over', 'the', 'field', 'bleating', 'for', 'his', 'mother', 'but', 'not', '
# ...

# %% [markdown]
# # <font color = 'red'> **Adopting MK316's script (as of 05NOV23)**

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/ms624atyale/Data_Class/main/PG%20Aesop%20Lexical%20Diversity/Aesop4Child_BodyLesson_Episode%23_Part%23_NoTitle_StatBase_Edit.txt'
df1 = pd.read_csv(url, sep='@') #separator 표시. other examples are sep='\t', etc.
df1
# Out:
#                                                   Text Episode  Part
# 0    “ There was once a little Kid whose growing ho...     EP1     1
# 1    “ The Tortoise, you know, carries his house on...     EP2     1
# 2    “ \”Why in the world do you walk sideways like...     EP3     1
# 3    “ An Ox came down to a reedy pool to drink. As...     EP4     1
# 4    “ A Dog and a Cock, who were the best of frien...     EP5     1
# ..                                                 ...     ...   ...
# 142  “ A pack of Wolves lurked near the Sheep pastu...    EP17     7
# 143  “ A Fox was caught in a trap one fine morning,...    EP18     7
# 144  “ An Ass found a Lion's skin left in the fores...    EP19     7
# 145  “ A poor Fisherman, who lived on the fish he c...    EP20     7
# 146  “ Once there were two Cocks living in the same...    EP21     7
#
# [147 rows x 3 columns]

# %% [markdown]
# ###Adding a colum with length info
# - Data: df2 = df1

# %%
df2 = df1

# %%
# !pip install textstat
import textstat
df2['N_Sents'] = df2['Text'].apply(textstat.sentence_count)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 32.6 MB/s eta 0:00:00
# ...

# %%
# Added column:  Splitted words, Length of splitted words
tsplit = []
splen = []

for i in range(0, len(df2['Text'])):
  TSP = df2['Text'][i].split()
  SPLEN = len(TSP)
  tsplit.append(TSP)
  splen.append(SPLEN)
  # print(TSP)

df2['Splits'] = tsplit
df2['N_Words'] = splen
df2
# Out:
#                                                   Text Episode  Part  N_Sents  \
# 0    “ There was once a little Kid whose growing ho...     EP1     1       20
# 1    “ The Tortoise, you know, carries his house on...     EP2     1       17
# 2    “ \”Why in the world do you walk sideways like...     EP3     1        8
# 3    “ An Ox came down to a reedy pool to drink. As...     EP4     1       12
# 4    “ A Dog and a Cock, who were the best of frien...     EP5     1       19
# ..                                                 ...     ...   ...      ...
# 142  “ A pack of Wolves lurked near the Sheep pastu...    EP17     7        9
# 143  “ A Fox was caught in a trap one fine morning,...    EP18     7       11
# 144  “ An Ass found a Lion's skin left in the fores...    EP19     7        8
# 145  “ A poor Fisherman, who lived on the fish he c...    EP20     7        8
# 146  “ Once there were two Cocks living in the same...    EP21     7        7
#
# ...

# %%
#@markdown {re} count syllables: count_syllables(word)
import re

def count_syllables(word):
    return len(
        re.findall('(?!e$)[aeiouy]+', word, re.I) +
        re.findall('^[^aeiouy]*e$', word, re.I)
    )

# %%
# function created
count_syllables("syllabilifcation")
# Out:
# 6

# %%
#TEST JUST FOR A TEST for The Aesop for Children EP1, PRT1
obj="""
There was once a little Kid whose growing horns made him think he was a grown-up Billy Goat and able to take care of himself. So one evening when the flock started home from the pasture and his mother called, the Kid paid no heed and kept right on nibbling the tender grass. A little later when he lifted his head, the flock was gone. He was all alone. The sun was sinking. Long shadows came creeping over the ground. A chilly little wind came creeping with them making scary noises in the grass. The Kid shivered as he thought of the terrible Wolf. Then he started wildly over the field, bleating for his mother. But not half-way, near a clump of trees, there was the Wolf! The Kid knew there was little hope for him.Please, Mr. Wolf, he said trembling, I know you are going to eat me. But first please pipe me a tune, for I want to dance and be merry as long as I can. The Wolf liked the idea of a little music before eating, so he struck up a merry tune and the Kid leaped and frisked gaily. Meanwhile, the flock was moving slowly homeward. In the still evening air the Wolf's piping carried far. The Shepherd Dogs pricked up their ears. They recognized the song the Wolf sings before a feast, and in a moment they were racing back to the pasture. The Wolf's song ended suddenly, and as he ran, with the Dogs at his heels, he called himself a fool for turning piper to please a Kid, when he should have stuck to his butcher's trade. Do not let anything turn you from your purpose.
"""
from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

#The way to calculate words are different from Lexical Diversity in this script using TextStat Library.
# Out:
# count word tokens: 290

# %%
#@markdown Adding a column: String length
length = []

for i in range(0, len(df2['Text'])):
  LEN = len(df2['Text'][i])
  length.append(LEN)
df2['String'] = length
df2
# Out:
#                                                   Text Episode  Part  N_Sents  \
# 0    “ There was once a little Kid whose growing ho...     EP1     1       20
# 1    “ The Tortoise, you know, carries his house on...     EP2     1       17
# 2    “ \”Why in the world do you walk sideways like...     EP3     1        8
# 3    “ An Ox came down to a reedy pool to drink. As...     EP4     1       12
# 4    “ A Dog and a Cock, who were the best of frien...     EP5     1       19
# ..                                                 ...     ...   ...      ...
# 142  “ A pack of Wolves lurked near the Sheep pastu...    EP17     7        9
# 143  “ A Fox was caught in a trap one fine morning,...    EP18     7       11
# 144  “ An Ass found a Lion's skin left in the fores...    EP19     7        8
# 145  “ A poor Fisherman, who lived on the fish he c...    EP20     7        8
# 146  “ Once there were two Cocks living in the same...    EP21     7        7
#
# ...

# %%
df2['N_Sents'].groupby(df2['Part']).describe()
# Out:
#       count       mean       std  min  25%   50%   75%   max
# Part
# 1      21.0  11.619048  4.212792  5.0  8.0  11.0  15.0  20.0
# 2      21.0  10.476190  4.365994  5.0  7.0   9.0  14.0  22.0
# 3      21.0  11.476190  5.259459  5.0  7.0  11.0  13.0  24.0
# 4      21.0  11.047619  5.454138  5.0  8.0   9.0  12.0  27.0
# 5      21.0  11.619048  6.644367  3.0  8.0  10.0  14.0  29.0
# 6      21.0  11.857143  5.816233  3.0  9.0  10.0  13.0  30.0
# 7      21.0  12.047619  5.064348  6.0  8.0  11.0  15.0  25.0

# %%
df2.describe()
# Out:
#              Part     N_Sents     N_Words       String
# count  147.000000  147.000000  147.000000   147.000000
# mean     4.000000   11.448980  175.251701   907.680272
# std      2.006838    5.229243   78.509911   408.739995
# min      1.000000    3.000000   59.000000   287.000000
# 25%      2.000000    8.000000  115.500000   599.000000
# 50%      4.000000   10.000000  162.000000   831.000000
# 75%      6.000000   14.000000  201.000000  1030.000000
# max      7.000000   30.000000  442.000000  2304.000000

# %%
from nltk.tokenize.regexp import WhitespaceTokenizer
from nltk.tokenize.regexp import WordPunctTokenizer

# %%
n = len(df2['N_Words'])
token_total = 0
type_total = 0
sent_total = 0
for i in range(0,n):
  tokens = len(WhitespaceTokenizer().tokenize(df2['Text'][i]))
  token_total = token_total + tokens
  types = len(set(df2['Text'][i]))
  type_total = type_total + types
  sents = df2["N_Sents"][i]
  sent_total = sent_total + sents

print("Total Number of tokens: %d"%token_total)
print("Total Number of types: %d"%type_total)
print("Total Number of sentences: %d"%sent_total)
# Out:
# Total Number of tokens: 25762
# Total Number of types: 5880
# Total Number of sentences: 1683

# %% [markdown]
# ##Text lengh and boxplot

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":140,"axes.labelsize":60},style="white") # font size doesn't work
# ax = sns.boxplot (y=df2)
# ax.set_ylim([0, 210])

sns.set_theme(style='white')
dd=pd.melt(df2,id_vars=['Episode'],value_vars=['N_Words'],var_name='Tokens')
ax = sns.boxplot(x='Episode',y='value',data=dd,hue='Tokens',palette="Accent")
ax.set_ylim([50,500]) #modified min/max value as of 05OCT23
ax.set(xlabel='Episodes of the Aesop for Children', ylabel='N of words (count)')
plt.savefig('boxplot_Episode.png')

# %% [markdown]
# ##Lexical Diversity Indices (10 types)

# %% [markdown]
# Getting LD indices

# %%
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# Added column: String length
lem = []

for i in range(0, len(df2['Text'])):
  LEM = ld.flemmatize(df2['Text'][i])
  lem.append(LEM)

df2['Lemma'] = lem

# %%
# ADD LD indices

#1. Create empty lists.
TTR = []
RTTR = []
LogTTR = []
MassTTR = []
MSTTR = []
MATTR = []
HDD = []
MTLD = []
MTLD_wrap = []
MTLD_bid = []

# 2. Getting LD index values for each cell:

for i in range(0, len(df2['Lemma'])):
  flt = df2['Lemma'][i]
  ttr = ld.ttr(flt)
  rttr = ld.root_ttr(flt)
  logttr = ld.log_ttr(flt)
  mass = ld.maas_ttr(flt)
  msttr = ld.msttr(flt)
  mattr = ld.mattr(flt)
  hdd = ld.hdd(flt)
  mtld = ld.mtld(flt)
  mtld_wrap = ld.mtld_ma_wrap(flt)
  mtld_bid = ld.mtld_ma_bid(flt)

  # Add values to each list
  TTR.append(ttr)
  RTTR.append(rttr)
  LogTTR.append(logttr)
  MassTTR.append(mass)
  MSTTR.append(msttr)
  MATTR.append(mattr)
  HDD.append(hdd)
  MTLD.append(mtld)
  MTLD_wrap.append(mtld_wrap)
  MTLD_bid.append(mtld_bid)

# Add columns
df2['TTR'] = TTR
df2['RTTR'] = RTTR
df2['LogTTR'] = LogTTR
df2['MassTTR'] = MassTTR
df2['MSTTR'] = MSTTR
df2['MATTR'] = MATTR
df2['HDD'] = HDD
df2['MTLD'] = MTLD
df2['MTLD_wrap'] = MTLD_wrap
df2['MTLD_bid'] = MTLD_bid

# %% [markdown]
# N of sentences

# %%
# !pip install textstat
import textstat

# %% [markdown]
# Result file: N of sentences included

# %%
df2['N_Sents'] = df2['Text'].apply(textstat.sentence_count)
df2.to_csv('LD_result_with_Nsents.csv')

# %% [markdown]
# ## Result file

# %%
df2.describe()
# Out:
#              Part     N_Sents     N_Words       String         TTR  \
# count  147.000000  147.000000  147.000000   147.000000  147.000000
# mean     4.000000   11.448980  175.251701   907.680272    0.602890
# std      2.006838    5.229243   78.509911   408.739995    0.075168
# min      1.000000    3.000000   59.000000   287.000000    0.412844
# 25%      2.000000    8.000000  115.500000   599.000000    0.549783
# 50%      4.000000   10.000000  162.000000   831.000000    0.594595
# 75%      6.000000   14.000000  201.000000  1030.000000    0.648308
# max      7.000000   30.000000  442.000000  2304.000000    0.806452
#
#              RTTR      LogTTR     MassTTR       MSTTR       MATTR         HDD  \
# count  147.000000  147.000000  147.000000  147.000000  147.000000  147.000000
# mean     7.622373    0.899914    0.045192    0.775982    0.779073    0.805249
# std      0.910820    0.017869    0.005942    0.033881    0.034919    0.026559
# ...

# %%
df2['MATTR'].groupby(df2['Part']).describe()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# Part
# 1      21.0  0.772718  0.026030  0.733265  0.756438  0.767482  0.783238
# 2      21.0  0.782862  0.029436  0.722069  0.761844  0.785882  0.804413
# 3      21.0  0.772822  0.041440  0.698543  0.746263  0.769474  0.803280
# 4      21.0  0.774149  0.033223  0.708929  0.743830  0.784545  0.799034
# 5      21.0  0.767798  0.031292  0.721867  0.746323  0.754130  0.797813
# 6      21.0  0.788701  0.032275  0.722286  0.774496  0.800000  0.808889
# 7      21.0  0.794460  0.043726  0.702500  0.774603  0.799200  0.820391
#
#            max
# Part
# 1     0.846667
# 2     0.839747
# 3     0.856000
# 4     0.820000
# 5     0.846154
# 6     0.857288
# 7     0.878667

# %%
df2['MATTR'].describe()
# Out:
# count    147.000000
# mean       0.779073
# std        0.034919
# min        0.698543
# 25%        0.752156
# 50%        0.780276
# 75%        0.803750
# max        0.878667
# Name: MATTR, dtype: float64

# %%
df2['HDD'].groupby(df2['Part']).describe()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# Part
# 1      21.0  0.803562  0.020754  0.767755  0.796979  0.802820  0.813276
# 2      21.0  0.807510  0.020543  0.769214  0.790457  0.803138  0.822668
# 3      21.0  0.803634  0.028729  0.749483  0.784889  0.804480  0.820828
# 4      21.0  0.800841  0.022584  0.761002  0.784764  0.798951  0.824166
# 5      21.0  0.803173  0.024150  0.763854  0.788506  0.796156  0.821757
# 6      21.0  0.810940  0.033090  0.745297  0.794122  0.821721  0.830649
# 7      21.0  0.807080  0.034779  0.724798  0.794716  0.814855  0.829264
#
#            max
# Part
# 1     0.857806
# 2     0.844577
# 3     0.852148
# 4     0.836523
# 5     0.859069
# 6     0.877142
# 7     0.862733

# %%
df2['HDD'].describe()
# Out:
# count    147.000000
# mean       0.805249
# std        0.026559
# min        0.724798
# 25%        0.788756
# 50%        0.804417
# 75%        0.824145
# max        0.877142
# Name: HDD, dtype: float64

# %% [markdown]
# Plotting

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(8,6),"font.size":40,"axes.titlesize":140,"axes.labelsize":60},style="white") # font size doesn't work
# ax = sns.boxplot (y=df2)
# ax.set_ylim([0, 500]) #modified from y=210 to y=500(05OCT23)

sns.set_theme(style='white')
dd=pd.melt(df2,id_vars=['Part'],value_vars=['N_Words'],var_name='Tokens')
ax = sns.boxplot(x='Part',y='value',data=dd,hue='Tokens',palette="Accent")
ax.set_ylim([50,500])
ax.set(xlabel='Part', ylabel='N of words (count)')
plt.savefig('boxplot_Nwords.png')

# %%
sns.kdeplot(x='N_Words', data=df2, hue='Part', common_norm=False);
plt.title("Kernel Density Function")
plt.savefig('Density_Nsplit.png')

# %%
sns.scatterplot(data=df2, x="Part", y="N_Words")
sns.rugplot(data=df2, x="Part", y="N_Words", height=.1)
plt.savefig('Rug_Nsplit.png')

# %% [markdown]
# 문항별 어휘수 및 문장수

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df2, x="Part", y="N_Words")
ax = sns.rugplot(data=df2, x="Part", y="N_Words", height=.1)
ax.set_ylim([10,500]) #modified from [90,200] to [10,500]
ax.set(xlabel='Each Part of The Aesop for Children', ylabel='N of words (count)')
plt.savefig('Rug_Nsplit_byQ.png')

# %% [markdown]
# # Lexical Diversity analysis: select TTR, MassTTR, MTLD, HDD

# %%
df3 = df2
for col in df3.columns:
    print(col)
# Out:
# Text
# Episode
# Part
# N_Sents
# Splits
# N_Words
# String
# Lemma
# TTR
# RTTR
# LogTTR
# MassTTR
# MSTTR
# MATTR
# HDD
# MTLD
# MTLD_wrap
# MTLD_bid

# %%
df3 = df2[['Part','Episode','N_Words','N_Sents','TTR','MSTTR','MATTR','HDD','MTLD']]
df3.head()
# Out:
#    Part Episode  N_Words  N_Sents       TTR  MSTTR     MATTR       HDD  \
# 0     1     EP1      285       20  0.536842  0.772  0.775424  0.813943
# 1     1     EP2      291       17  0.549828  0.804  0.792066  0.816526
# 2     1     EP3       95        8  0.642105  0.820  0.743043  0.798062
# 3     1     EP4      134       12  0.604478  0.800  0.750824  0.809381
# 4     1     EP5      308       19  0.535714  0.780  0.773745  0.802820
#
#         MTLD
# 0  80.278561
# 1  78.488159
# 2  73.381695
# 3  49.012951
# 4  68.226050

# %%
df3.groupby('Part')['TTR'].describe()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# Part
# 1      21.0  0.584476  0.068148  0.473868  0.536842  0.572165  0.628205
# 2      21.0  0.609786  0.062611  0.505226  0.569307  0.601124  0.655172
# 3      21.0  0.607500  0.080232  0.459770  0.549505  0.587838  0.680000
# 4      21.0  0.604494  0.059058  0.493671  0.572165  0.608466  0.642857
# 5      21.0  0.605683  0.093935  0.412844  0.536585  0.612903  0.661157
# 6      21.0  0.610912  0.082329  0.465608  0.561798  0.615385  0.641791
# 7      21.0  0.597381  0.081343  0.459524  0.540909  0.594737  0.628378
#
#            max
# Part
# 1     0.752577
# 2     0.716981
# 3     0.746479
# 4     0.729412
# 5     0.806452
# 6     0.779661
# 7     0.772152

# %%
df3.groupby('Part')['MSTTR'].describe()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# Part
# 1      21.0  0.776533  0.032986  0.700000  0.760000  0.773333  0.800000
# 2      21.0  0.777848  0.025993  0.736000  0.755000  0.780000  0.793333
# 3      21.0  0.764746  0.038969  0.685000  0.740000  0.760000  0.800000
# 4      21.0  0.777823  0.027763  0.730000  0.753333  0.786667  0.800000
# 5      21.0  0.765913  0.035091  0.710000  0.745000  0.760000  0.800000
# 6      21.0  0.788095  0.029530  0.733333  0.780000  0.786667  0.805000
# 7      21.0  0.780913  0.042394  0.686667  0.773333  0.790000  0.802500
#
#            max
# Part
# 1     0.840000
# 2     0.833333
# 3     0.830000
# 4     0.833333
# 5     0.820000
# 6     0.860000
# 7     0.860000

# %%
df3['TTR'].describe()
# Out:
# count    147.000000
# mean       0.602890
# std        0.075168
# min        0.412844
# 25%        0.549783
# 50%        0.594595
# 75%        0.648308
# max        0.806452
# Name: TTR, dtype: float64

# %%
df3['MSTTR'].describe()
# Out:
# count    147.000000
# mean       0.775982
# std        0.033881
# min        0.685000
# 25%        0.750000
# 50%        0.780000
# 75%        0.800000
# max        0.860000
# Name: MSTTR, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(8,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
# sns.set_theme(style='white')
dd=pd.melt(df3,id_vars=['Part'],value_vars=['MSTTR'],var_name='LD index')
ax = sns.boxplot(x='Part',y='value',data=dd,hue='LD index',palette="Accent")
ax.set_ylim([.6,.9])
ax.set(xlabel='Part', ylabel='MSTTR')
plt.savefig('boxplot_MSTTR_by_part.png')

# %%
sns.kdeplot(x='MSTTR', data=df3, hue='Part', common_norm=False);
plt.title("Kernel Density Function")
plt.savefig('Density_MTLD.png')

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df3, x="Part", y="MSTTR")
ax = sns.rugplot(data=df3, x="Part", y="MSTTR", height=.1)
ax.set_ylim([0,1])
ax.set_xlim([-1,8])
ax.set(xlabel='Part', ylabel='MSTTR index')
plt.savefig('Rug_MSTTR_byPart.png')

# %% [markdown]
# ##MATTR

# %%
sns.kdeplot(x='MATTR', data=df3, hue='Part', common_norm=False);
plt.title("Kernel Density Function")
plt.savefig('Density_MATTR.png')

# %%
df3.groupby('Part')['MATTR'].describe()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# Part
# 1      21.0  0.772718  0.026030  0.733265  0.756438  0.767482  0.783238
# 2      21.0  0.782862  0.029436  0.722069  0.761844  0.785882  0.804413
# 3      21.0  0.772822  0.041440  0.698543  0.746263  0.769474  0.803280
# 4      21.0  0.774149  0.033223  0.708929  0.743830  0.784545  0.799034
# 5      21.0  0.767798  0.031292  0.721867  0.746323  0.754130  0.797813
# 6      21.0  0.788701  0.032275  0.722286  0.774496  0.800000  0.808889
# 7      21.0  0.794460  0.043726  0.702500  0.774603  0.799200  0.820391
#
#            max
# Part
# 1     0.846667
# 2     0.839747
# 3     0.856000
# 4     0.820000
# 5     0.846154
# 6     0.857288
# 7     0.878667

# %% [markdown]
# ##Readability indices & Plotting for papers

# %%
from typing import TextIO
FRE = []
FKG = []
GF = []
ARI = []
CLI = []
LWF = []
DCRS = []
TS = []

for i in range(0, len(df2['Text'])):
  text = df2['Text'][i]
  fre = textstat.flesch_reading_ease(text)
  fkg = textstat.flesch_kincaid_grade(text)
  gf = textstat.gunning_fog(text)
  ari = textstat.automated_readability_index(text)
  cli = textstat.coleman_liau_index(text)
  lwf = textstat.linsear_write_formula(text)
  dcrs = textstat.dale_chall_readability_score(text)
  ts = textstat.text_standard(text)

  FRE.append(fre)
  FKG.append(fkg)
  GF.append(gf)
  ARI.append(ari)
  CLI.append(cli)
  LWF.append(lwf)
  DCRS.append(dcrs)
  TS.append(ts)


df3['FRE'] = FRE
df3['FKG'] = FKG
df3['GF'] = GF
df3['ARI'] = ARI
df3['CLI'] = CLI
df3['LWF'] = LWF
df3['DCRS'] = DCRS
df3['TS'] = TS
# Out:
# <ipython-input-68-62d119fe0300>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['FRE'] = FRE
# <ipython-input-68-62d119fe0300>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['FKG'] = FKG
# <ipython-input-68-62d119fe0300>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# df3: LD(4 indices) + Readability

# %%
df3.to_csv('results_all.csv')

# %%
df3.head()
# Out:
#    Part                           Episode  N_Words  N_Sents       TTR  \
# 0     1            “THE WOLF AND THE KID”      285       20  0.536842
# 1     1      “THE TORTOISE AND THE DUCKS”      291       17  0.549828
# 2     1   “THE YOUNG CRAB AND HIS MOTHER”       95        8  0.642105
# 3     1            “THE FROGS AND THE OX”      134       12  0.604478
# 4     1  “THE DOG, THE COCK, AND THE FOX”      308       19  0.535714
#
#       MATTR       HDD       MTLD    FRE  FKG    GF  ARI   CLI      LWF  DCRS  \
# 0  0.775424  0.813943  80.278561  90.90  4.1  5.96  5.7  5.79   5.2500  6.90
# 1  0.792066  0.816526  78.488159  87.96  5.2  8.22  6.9  5.68  11.0000  6.17
# 2  0.743043  0.798062  73.381695  93.34  3.2  5.57  4.7  4.68   5.1875  5.57
# 3  0.750824  0.809381  49.012951  94.05  2.9  4.74  4.6  4.62   4.1000  5.97
# 4  0.773745  0.802820  68.226050  88.97  4.8  7.49  6.3  5.68  10.4000  6.96
#
#                   TS
# 0  5th and 6th grade
# 1  5th and 6th grade
# ...

# %%
#47/136 Where are the numbers from and what for? Ask MK316

# %%
a = df3[df3['FRE'] < 50]
a.shape
# Out:
# (0, 16)

# %%
df4 = df3
#df4 = df4[['Part','Episode','N_Splits','N_Sents','TTR','MTLD','FRE','FKG','GF','DCRS']] #Original from MK316
df4 = df4[['Part','Episode','N_Sents','TTR','MTLD','FRE','FKG','GF','DCRS']] #Modified, self-taught

# %%
sns.set(rc={'figure.figsize':(6,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df4, x="Part", y="FRE")
ax = sns.rugplot(data=df4, x="Part", y="FRE", height=.1)
ax.set_ylim([0,100])
# ax.set_xlim([2014,2023])
ax.set(xlabel='Part', ylabel='Flesch Reading Ease index')
ax.axhline(50, color="gray")
ax.axhline(30, color="red")
# ax.axhline(60)
# ax.axhline(70)
# ax.axhline(80)
# plt.text(8, 50, "An annotation", horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('Rug_FRE_byPart.png')

# %%
sns.set(rc={'figure.figsize':(6,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df4, x="Part", y="FKG")
ax = sns.rugplot(data=df4, x="Part", y="FKG", height=.1)
ax.set_ylim([0,20])
# ax.set_xlim([2014,2023])
ax.set(xlabel='Part', ylabel='Flesch Kincaid Grade')
ax.axhline(15, color="red")
ax.axhline(12, color="blue")
ax.axhline(6, color="gray")
# ax.axhline(60)
# ax.axhline(70)
# ax.axhline(80)
# plt.text(8, 50, "An annotation", horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('Rug_FKG_byPart.png')

# %%
a = df4.groupby('Part')['FKG'].describe()
a.to_csv('FKG_summary_by_Part.csv')

# %%
b = df4.groupby('Part')['FRE'].describe()
b.to_csv('FRE_summary_by_Part.csv')

# %%
b1 = df4.describe()
b1.to_csv('Readability_summary_total.csv')

# %% [markdown]
# ##Getting individual numbers for the paper
# -I don't get it. No matter what, I copied and work on being trained with code lines.

# %%
b2 = df4[15 <= df3['GF']]
b2.shape
# Out:
# (0, 9)

# %%
#WHY? 38/136

# %%
a1 = df4[10 <= df3['DCRS']]
a1.shape
# Out:
# (0, 9)

# %%
#WHY? 31/136

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df4, x="Episode", y="DCRS")
ax = sns.rugplot(data=df4, x="Episode", y="DCRS", height=.1)
ax.set_ylim([5,13])
# ax.set_xlim([2014,2023])
ax.set(xlabel='Question Number', ylabel='Dale-Chall Reading Score')
ax.axhline(10, color="red")
ax.axhline(9, color="blue")
# ax.axhline(6, color="gray")
# ax.axhline(60)
# ax.axhline(70)
# ax.axhline(80)
# plt.text(8, 50, "An annotation", horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('Rug_DCRS_byEpisode.png')

# %%
a2 = df4[10 <= df3['DCRS']]
a2.shape
# Out:
# (0, 9)

# %%
#??? 74/136

# %% [markdown]
# ## Pie chart of readability indices
# -Origianl from MK316. Later I need to modify after working on it.

# %%
import matplotlib.pyplot as plt
import seaborn

sns.set(rc={'figure.figsize':(6,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":30},style="white") # font size doesn't work
# declaring data
data = [44, 45, 40, 41, 39]
keys = ['Class 1', 'Class 2', 'CLass 3', 'Class 4', 'Class 5']

# declaring exploding pie
explode = [0, 0.1, 0, 0, 0]
# define Seaborn color palette to use
palette_color = seaborn.color_palette("Set2")

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%')

# displaying chart
plt.show()

# %% [markdown]
# ## Data cut (categorize)

# %%
import pandas as pd
df4.head()
# Out:
#    Part                           Episode  N_Sents       TTR       MTLD  \
# 0     1            “THE WOLF AND THE KID”       20  0.536842  80.278561
# 1     1      “THE TORTOISE AND THE DUCKS”       17  0.549828  78.488159
# 2     1   “THE YOUNG CRAB AND HIS MOTHER”        8  0.642105  73.381695
# 3     1            “THE FROGS AND THE OX”       12  0.604478  49.012951
# 4     1  “THE DOG, THE COCK, AND THE FOX”       19  0.535714  68.226050
#
#      FRE  FKG    GF  DCRS
# 0  90.90  4.1  5.96  6.90
# 1  87.96  5.2  8.22  6.17
# 2  93.34  3.2  5.57  5.57
# 3  94.05  2.9  4.74  5.97
# 4  88.97  4.8  7.49  6.96

# %%
## pd.cut: how to use

b1 = pd.cut(df4['FRE'], bins=[0, 30, 50, 60,100], include_lowest=True, labels=['Very difficult', 'Difficult', 'Appropriate',"Easy"])

count = b1.value_counts()
print(count)
# Out:
# Easy              5
# Very difficult    0
# Difficult         0
# Appropriate       0
# Name: FRE, dtype: int64

# %%
## pd.cut: how to use

b1 = pd.cut(df4['GF'], bins=[0, 9, 13, 16,20], include_lowest=True, labels=["Easy", 'Appropriate', 'Difficult', 'Very difficult'])

count = b1.value_counts()
print(count)
# Out:
# Easy              5
# Appropriate       0
# Difficult         0
# Very difficult    0
# Name: GF, dtype: int64

# %%
## pd.cut: how to use

b1 = pd.cut(df4['DCRS'], bins=[0, 7, 8, 9, 10], include_lowest=True, labels=["Easy", 'Appropriate', 'Difficult', 'Very difficult'])

count = b1.value_counts()
print(count)
# Out:
# Easy              5
# Appropriate       0
# Difficult         0
# Very difficult    0
# Name: DCRS, dtype: int64

# %%
b1
# Out:
# 0    Easy
# 1    Easy
# 2    Easy
# 3    Easy
# 4    Easy
# Name: DCRS, dtype: category
# Categories (4, object): ['Easy' < 'Appropriate' < 'Difficult' < 'Very difficult']

# %% [markdown]
# [1] FRE pie chart

# %%
import matplotlib.pyplot as plt
import seaborn

sns.set(rc={'figure.figsize':(6,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":30},style="white") # font size doesn't work

# declaring data
data = [18, 47, 31, 40]
keys = ['Very difficult', 'Difficult','Appropriate','Easy']
# declaring exploding pie
explode = [0.1, 0, 0, 0]
# define Seaborn color palette to use
palette_color = seaborn.color_palette("Set2")

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%')

# displaying chart
ax.set_title("Flesch Reading Ease")

plt.savefig('Pie_FRE.png')
plt.show()

# %% [markdown]
# [2] Gunning-Fog pie

# %%
import matplotlib.pyplot as plt
import seaborn

sns.set(rc={'figure.figsize':(6,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":30},style="white") # font size doesn't work

# declaring data
data = [21, 45, 47, 17]
keys = ['Very difficult', 'Difficult','Appropriate','Easy']
# declaring exploding pie
explode = [0.1, 0, 0, 0]
# define Seaborn color palette to use
palette_color = seaborn.color_palette("Set2")

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%')

# displaying chart
ax.set_title("Gunning-Fog")

plt.savefig('Pie_GF.png')
plt.show()

# %% [markdown]
# [3] Dale-Chall pie

# %%
import matplotlib.pyplot as plt
import seaborn

sns.set(rc={'figure.figsize':(6,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":30},style="white") # font size doesn't work

# declaring data
data = [44, 41, 15, 6]
keys = ['Very difficult', 'Difficult','Appropriate','Easy']
# declaring exploding pie
explode = [0.1, 0, 0, 0]
# define Seaborn color palette to use
palette_color = seaborn.color_palette("Set2")

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%')

# displaying chart
ax.set_title("Dale-Chall")

plt.savefig('Pie_DC.png')
plt.show()

# %% [markdown]
# Statistic analysis for the data

# %%
#df5 = df3[['Part','Episode','N_Splits','N_Sents','TTR','MATTR','MTLD','HDD','FRE','FKG','GF','DCRS']] #Original with 'N_Splits
#df5.head()

df5 = df3[['Part','Episode','N_Sents','TTR','MATTR','MTLD','HDD','FRE','FKG','GF','DCRS']]
df5.head()
# Out:
#    Part                           Episode  N_Sents       TTR     MATTR  \
# 0     1            “THE WOLF AND THE KID”       20  0.536842  0.775424
# 1     1      “THE TORTOISE AND THE DUCKS”       17  0.549828  0.792066
# 2     1   “THE YOUNG CRAB AND HIS MOTHER”        8  0.642105  0.743043
# 3     1            “THE FROGS AND THE OX”       12  0.604478  0.750824
# 4     1  “THE DOG, THE COCK, AND THE FOX”       19  0.535714  0.773745
#
#         MTLD       HDD    FRE  FKG    GF  DCRS
# 0  80.278561  0.813943  90.90  4.1  5.96  6.90
# 1  78.488159  0.816526  87.96  5.2  8.22  6.17
# 2  73.381695  0.798062  93.34  3.2  5.57  5.57
# 3  49.012951  0.809381  94.05  2.9  4.74  5.97
# 4  68.226050  0.802820  88.97  4.8  7.49  6.96

# %%
ld = df5[['TTR','MATTR','MTLD','HDD']]

# %%
corrMatrix = ld.corr()
corrMatrix
# Out:
#             TTR     MATTR      MTLD       HDD
# TTR    1.000000 -0.875575 -0.389218 -0.593094
# MATTR -0.875575  1.000000  0.545925  0.728857
# MTLD  -0.389218  0.545925  1.000000  0.207689
# HDD   -0.593094  0.728857  0.207689  1.000000

# %%
import seaborn as sn
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(12,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":30},style="white")

sn.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# # Others

# %% [markdown]
# The Gunning Fog index: It generates a grade level between 0 and 20. It estimates the education level required to understand the text. Too many different words per thoughsand, not enough simple sentences, too difficult for the inteded audience.

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df4, x="Year", y="GF")
ax = sns.rugplot(data=df4, x="Year", y="GF", height=.1)
ax.set_ylim([0,20])
# ax.set_xlim([0,150])
ax.set(xlabel='Year', ylabel='Dale-Chall Reading Score')
ax.axhline(15, color="red")
ax.axhline(12, color="blue")
ax.axhline(9, color="gray")
# ax.axhline(60)
# ax.axhline(70)
# ax.axhline(80)
# plt.text(8, 50, "An annotation", horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('GF_scatter.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-483dfeabf263> in <cell line: 2>()
#       1 sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
# ----> 2 sns.scatterplot(data=df4, x="Year", y="GF")
#       3 ax = sns.rugplot(data=df4, x="Year", y="GF", height=.1)
#       4 ax.set_ylim([0,20])
#       5 # ax.set_xlim([0,150])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     740
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     743
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#
# ...

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df4, x="Year", y="DCRS")
ax = sns.rugplot(data=df4, x="Year", y="DCRS", height=.1)
ax.set_ylim([5,13])
# ax.set_xlim([0,150])
ax.set(xlabel='Year', ylabel='Dale-Chall Reading Score')
# ax.axhline(15, color="red")
ax.axhline(10, color="red")
ax.axhline(9, color="blue")
# ax.axhline(60)
# ax.axhline(70)
# ax.axhline(80)
# plt.text(8, 50, "An annotation", horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('DCRS_scatter.png')

# %%
df4['DCRS'].describe()

# %%
plt.hist(df4['DCRS'], binwidth=1)

# %%
ordered_ttr = list(df2['TTR']).sort()
ordered_ttr

# %%
a1 = df2[['N_Splits','TTR','MSTTR']]
a2 = a1.sort_values(by=['N_Splits'])
a2

# %%
df3 = df2.sort_values(by=['N_Splits'])

# %%
f = plt.figure(figsize=(10, 10))
plt.scatter(df2['N_Splits'],df2['TTR'],  label='TTR')
# plt.scatter(df2['N_Splits'],df2['LogTTR'],  label='LogTTR')
# plt.scatter(df2['N_Splits'],df2['MSTTR'],  label='MSTTR')
plt.legend()

# %% [markdown]
# Linear regression of TTR and Length

# %%
# importing the required library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# # f = plt.figure(figsize=(10, 10))
# fig, (ax1, ax2) = plt.subplots(1, 2)
# fig.suptitle('Horizontally stacked subplots')
# data
df = df2

# scatter plot with regression
# line(by default)
sns.lmplot(x ='N_Splits', y ='TTR', data = df)

# Show the plot
plt.show()

# %%
# Residual plots
sns.residplot(x ='N_Splits', y ='TTR', data = df)

# %%
sns.lmplot(x ='N_Splits', y ='MTLD', data = df)

# Show the plot
plt.show()

# %%
# Residual plots
sns.residplot(x ='N_Splits', y ='MTLD', data = df)

# %%
import statsmodels.api as sm

X = df["N_Splits"]
y = df["TTR"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()

# %%
X = df["N_Splits"]
y = df["MTLD"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()

# %%
Style: additionaal Boxplots 아래 하단은 추후 복사해 공부하고 적용하기
