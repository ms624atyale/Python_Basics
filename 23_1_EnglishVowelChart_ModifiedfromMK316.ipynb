# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/Python_Basics/blob/main/23_1_EnglishVowelChart_ModifiedfromMK316.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐹 🐾 🍩 Vocabulary Drills
#
# #📘 **Topic 03 Pronunciation teaching**
#
# **Table of Contents:**
# 1. **gTTS**
# * The gTTS library is a Python wrapper for the Google Text-to-Speech(TTS) API(Application Programming Interface). It allows you to convert text into speech using Google's text-to-speech service.
# * The gTTS library provides a convenient way to generate speech from text by utilizing the power of Google's TTS engine. It allows you to specify the text to be converted, choose the desired language, and control various parameters such as the speed of speech.
#
# 2. **CMU**(Carnegie Mellon University) pronunciation dictionary .
#
# 3. Exposure to Keyword pronunciation (using 📊_frequency distribution, gTTS_)
# 4. English rhyming (using 📃_CMU dictionary_): e.g., night, right, bite, etc.
# 5. Learning English vowels with rhyming words.🎼🎼🎼

# %% [markdown]
# ## 🐣 <font color = 'brown'> **Preprocessing of the text** ⤵️
#
# **For Your Information**
#
# **[NLTK package & punkt module](https://www.askpython.com/python-modules/nltk-punkt)**
#
# **[corpus-toolkit package](https://kristopherkyle.github.io/corpus_toolkit/)**
#
#   - **pip**
#     - "pip" is a package-management system written in Python and is used to install and manage software packages.
#     - "pip install" will execute the setup.py file in the current directory.
#
#   -[package] **corpus-toolkit** is used for corpus analysis.
#
#   -[package] **NLTK** (Natural Language Toolkit) is used in Python to implement programs under the domain of Natural Language Processing. It contains a variety of libraries for various purposes like text classification, parsing, stemming, tokenizing, etc.
#   -[module] In NLTK, **PUNKT** is an unsupervised trainable model, which means it can be trained on unlabeled data (Data that has not been tagged with information identifying its characteristics, properties, or categories is referred to as unlabeled data.) It generates a list of sentences from a text by developing a model for words that start sentences, prepositional phrases, and abbreviations using an unsupervised technique. Without first being put to use, it has to be trained on a sizable amount of plaintext in the intended language.

# %% [markdown]
# ## Nomalization
# ###**Stemming**
# * am → am, having → hav
#
# ###**Lemmatization**
# * am → be, having → have

# %%
#@markdown # ✏️ <font color = 'red'> **Student's activity 1** ⤵️
#@markdown ### 1. 👀 <font color = 'brown'> **Install and import packages**

# !pip install corpus-toolkit

import nltk               
from nltk.tokenize import word_tokenize, sent_tokenize  
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: corpus-toolkit in /usr/local/lib/python3.10/dist-packages (0.32)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# 💾 Sample text: [Aesop fable: The Heron](https://raw.githubusercontent.com/MK316/workshop22/main/data/TheHeron.txt) Copy and get it ready to past below :-)

# %%
#@markdown # ✏️ <font color = 'red'> **Student's activity 2** ⤵️
#@markdown #### 2.👀 <font color = 'brown'> **Paste your text here for analysis: (text)**
#@markdown #### 3.👀 <font color = 'brown'> **Create a folder named "txtdata" for further processing**
#@markdown #### 4.👀 <font color = 'brown'> **Enter text in the input box so that it can be saved on the file under 'txtdata' folder**


text = input('Enter a text either by typing or doing a copy & paste:')

import os 
os.mkdir("txtdata") 

with open('txtdata/mytext.txt','wt') as f:
  f.write(text)
# Out:
# Enter a text either by typing or doing a copy & paste:A Heron was walking sedately along the bank of a stream, his eyes on the clear water, and his long neck and pointed bill ready to snap up a likely morsel for his breakfast. The clear water swarmed with fish, but Master Heron was hard to please that morning. "No small fry for me," he said. "Such scanty fare is not fit for a Heron. "Now a fine young Perch swam near. "No indeed," said the Heron. "I wouldn't even trouble to open my beak for anything like that!" As the sun rose, the fish left the shallow water near the shore and swam below into the cool depths toward the middle. The Heron saw no more fish, and very glad was he at last to breakfast on a tiny Snail. Do not be too hard to suit or you may have to be content with the worst or with nothing at all.
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-17-a7778dfb827e> in <cell line: 6>()
#       4
#       5 import os
# ----> 6 os.mkdir("txtdata")
#       7
#       8 with open('txtdata/mytext.txt','wt') as f:
#
# FileExistsError: [Errno 17] File exists: 'txtdata'

# %% [markdown]
# >## 🐣 **Frequency analysis:** your actions required two times ⤵️
#
#   - [Regular Expression](https://www3.ntu.edu.sg/home/ehchua/programming/howto/Regexe.html)
#
# archive: #The " \w " means "any word character" which usually means alphanumeric (letters[a-zA-Z], numbers[0-9]) plus underscore (_).

# %%
#@markdown # ✏️ <font color = 'red'> **Student's activity 3** ⤵️
#@markdown 5.👀 Tokenize using Regular expression & converting eveything to lower case
#??getting frequency list with tagging information

from nltk.tokenize import RegexpTokenizer
retokenize = RegexpTokenizer("[\w]+") 
words = retokenize.tokenize(text) 

# Lower case
wordlist = []
for w in words:
  w1 = w.lower()
  wordlist.append(w1)

words = wordlist
print('Word count before excluding stopwords: %d'%len(words))
# Out:
# Word count before excluding stopwords: 154

# %%
#@markdown # ✏️ <font color = 'red'> **Student's activity 4** ⤵️
#@markdown 6.👀Remove stopwords 

from nltk.corpus import stopwords 
nltk.download("stopwords") 

words = [w for w in words if not w in stopwords.words('english')] 
print('Word count after excluding stopwords: %d'%len(words))
# Out:
# Word count after excluding stopwords: 75
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#@markdown 7.👀POS Tagging (abbr. Part of Speech (i.e., grammatical categories))

from corpus_toolkit import corpus_tools as ct #from ExtPackageName import ModuleName

brown_corp = ct.ldcorpus("txtdata") #load and read text files under 'txtdata' directory
tok_corp = ct.tokenize(brown_corp)  #tokenize corpus - by default this lemmatizes as well
brown_freq = ct.frequency(tok_corp) #creates a frequency dictionary

ct.write_corpus("tagged_txt",ct.tag(ct.ldcorpus("txtdata"))) #loading & reading under the txtdata folder 한 것에 tagging per token하고, 이 결과를 tagged_txt라는 파일로 저장하기. 
tagged_freq = ct.frequency(ct.reload("tagged_txt")) #POS tagging per token을 저장한 tagged_txt 파일을 메모리에 재전송 하고, 이에 대한 데이터에 빈도수 계산
# ct.head(tagged_freq, hits = 10) #토큰 별 POS-tagged freq 계산한 결과를 처음 10 개에 대하여 보여 달라. 

#@markdown 8.👀 Saving the result above as a csv file with POS information

import pandas as pd #import PyIntPackage 
data_dict = tagged_freq #Assign POS-tagged freq to "data_dict" variable 
data_items = data_dict.items() #POS-tagged freq "data_dic"를 항목별로 정리
data_list = list(data_items) #항목별로 정리된 POS-tagged freq 데이터를 리스트로 변환
df = pd.DataFrame(data_list) #🍄데이터 리스트가 된 결과를 판다스 페키지의 DataFrame 함수를 적용해 그 결과를 "df" variable. 

df.columns=['Tagged_words','Freq'] #🍄 "df"variable 열을 문자열 리스트로 하여 두 요소를 쓴다. 
mycol = list(df['Tagged_words']) # "df" variable에 "Tagged_words"를 리스트화 하여 "mycol" variable 로 할당

# print(df)

# Word, POS into dataframe

wordlist = [] #"wordlist" variable에 empty list 만들어 놓고
cat = [] #"cat" variable에 empty list 만들어 놓고

for w in mycol: #POS-tagged freq된 tokens를 항목화 하고, 이를 리스트화 한 결과 중에서 'Tagged_words'를 리스트화 한 "mycol" variable에서 단어를 하나씩 끄집어 낸다.
  w1 = w.split("_") #끄집어 낸 단어를 '_'기호를 사용하여 분리하고 이를 'w1' variable에 할당
  wordlist.append(w1[0]) #"wordlist" variable에 '_'기호로 분리된 단어의 첫번째 요소를 추가한다
  cat.append(w1[1]) #위에 생성해 놓은 empty cat list에 '_'기호를 사용해 분리한 단어의 첫 번째 요소를 추가한다.

df['Word'] = wordlist #🍄???
df['POS'] = cat #🍄???

#@markdown 9.👀 🚩 Sorting by? Answer [pop up box]

print("Sorting by Frequency (type '1'), POS & Freq (type '2'), or by Word alphabetically (type '3')")

sorting = input()

for t in sorting:
  if t == "1":
    df = df.sort_values(by=['Freq'], ascending = False)
  if t == "2":
    df = df.sort_values(by=['POS', 'Freq'], ascending = False)
  if t == "3":
    df = df.sort_values(by=['Word'], ascending = True)
  else:
    print("Type 1, 2, or 3")
df['Index'] = range(1,len(df['POS'])+1)

df = df[["Index", "POS", "Word","Freq"]]
# print df.to_string(index=False)

#@markdown 10.👀 🚩 Saving file? Answer [pop up box]

print('Save it as a file? (y/n)')
saving = input()

for s in saving:
  if s == "y":
    with open('pos_wordlist.csv','w') as f:
      df.to_csv(f)
    print('File is saved: pos_wordlist.csv')
  if s == "n":
    print('No file will be saved.')

df.head()

# %%
#@markdown # ✏️ <font color = 'red'> **Student's activity 5** ⤵️
#@markdown 7.👀POS Tagging (abbr. Part of Speech (i.e., grammatical categories))

#@markdown 8.👀 Saving the result above as a csv file with POS information

#@markdown 9.👀 🚩 Sorting by? Answer [pop up box]

#@markdown 10.👀 🚩 Saving file? Answer [pop up box]


from corpus_toolkit import corpus_tools as ct #from ExtPackageName import ModuleName

brown_corp = ct.ldcorpus("txtdata") #load and read text files under 'txtdata' directory
tok_corp = ct.tokenize(brown_corp)  #tokenize corpus - by default this lemmatizes as well
brown_freq = ct.frequency(tok_corp) #creates a frequency dictionary

ct.write_corpus("tagged_txt",ct.tag(ct.ldcorpus("txtdata"))) #as of May 10, 2023

tagged_freq = ct.frequency(ct.reload("tagged_txt"))
# ct.head(tagged_freq, hits = 10)

#8.👀
import pandas as pd
data_dict = tagged_freq
data_items = data_dict. items()
data_list = list(data_items)
df = pd.DataFrame(data_list)

df.columns=['Tagged_words','Freq']

mycol = list(df['Tagged_words'])

# print(df)

# Word, POS into dataframe

wlist = []
cat = []

for w in mycol:
  w1 = w.split("_")
  wlist.append(w1[0])
  cat.append(w1[1])

df['Word'] = wlist
df['POS'] = cat


#9.👀
print("Sorting by Frequency (type '1'), POS & Freq (type '2'), or by Word alphabetically (type '3')")
sorting = input()

for t in sorting:
  if t == "1":
    df = df.sort_values(by=['Freq'], ascending = False)
  if t == "2":
    df = df.sort_values(by=['POS', 'Freq'], ascending = False)
  if t == "3":
    df = df.sort_values(by=['Word'], ascending = True)
  else:
    print("Type 1, 2, or 3")
df['Index'] = range(1,len(df['POS'])+1)

df = df[["Index", "POS", "Word","Freq"]]
# print df.to_string(index=False)



#10.👀
print('Save it as a file? (y/n)')
saving = input()

for s in saving:
  if s == "y":
    with open('pos_wordlist.csv','w') as f:
      df.to_csv(f)
    print('File is saved: pos_wordlist.csv')
  if s == "n":
    print('No file will be saved.')

df.head()
# Out:
# Processing mytext.txt (1 of 1 files)
# Writing files to existing folder
# Processing mytext.txt (1 of 1 files)
# Processing 1.txt (1 of 1 files)
# Sorting by Frequency (type '1'), POS & Freq (type '2'), or by Word alphabetically (type '3')
# 2
# Type 1, 2, or 3
# Save it as a file? (y/n)
# y
# File is saved: pos_wordlist.csv
#     Index   POS   Word  Freq
# 42      1  VERB    say     2
# 3       2  VERB   walk     1
# 18      3  VERB  point     1
# 22      4  VERB   snap     1
# 28      5  VERB  swarm     1

# %% [markdown]
# ## **[1] Generating audio file of word reading**
# Result file => df

# %%
#@markdown # ✏️ <font color = 'red'> **Student's activity 6** ⤵️ 
#@markdown 9.👀 {gTTS} package installation and import
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

# %%
#@markdown Word reading by gTTS:

#@markdown 🚩 Select word POS: 

word_POS_select = "NOUN" #@param = ["NOUN","VERB","ADJ","ADV","PROPN","ALL"]

wordlist = df[df['POS'] == word_POS_select]
wordlist = wordlist.sort_values(by=['Word'], ascending = True)

collist = list(wordlist['Word'])

print(collist)

#@markdown 🚩 Language to choose: (english, korean, french, spanish)
def tts(mytext):
  text_to_say = mytext

# Step ⓵ Language to choose:
  language_to_choose = "en" #@param ["en", "ko", "fr", 'es']
  # lang = language_to_choose
  language = language_to_choose
  print("Play language accent: %s"%language_to_choose)

  gtts_object = gTTS(text = text_to_say,
                     lang = language,
                    slow = False) 
  
  gtts_object.save("mytext.wav")
  return Audio("mytext.wav")

# join wordlist by adding '!': joining with '.' tend to yield an error of saying two words as one. 
text_to_say = '! '.join(collist)
intro_text = "Okay. I'm going to read a wordlist, so repeat after me."
text_to_say = intro_text + text_to_say
tts(text_to_say)
# Out:
# ['bank', 'beak', 'bill', 'breakfast', 'depth', 'eye', 'fare', 'fish', 'fry', 'middle', 'morning', 'morsel', 'neck', 'scanty', 'shore', 'stream', 'sun', 'swam', 'trouble', 'water']
# Play language accent: en
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##**[2] Rhyming words**
#
# **_Note:_** In the following, you'll get rhyming words from CMU dictionary.
# * [CMU pronounciation dictionary](http://www.speech.cs.cmu.edu/cgi-bin/cmudict)
#
# * [CMU tools](http://www.speech.cs.cmu.edu/tools/lextool.html)

# %% [markdown]
# 😊 Let's first set up target words for today.

# %%
#@markdown # ✏️ <font color = 'red'> **Student's activity 7** ⤵️ 
#@markdown 10.👀 **Step 1:** Install {pronouncing}
# %%capture
# !pip install pronouncing
# !pip install cmudict

import pronouncing
import cmudict

# %% [markdown]
# \[Description]:
#
# * For a target word (your choice), we'll find rhyming words with same number of syllables. _e.g., 'grow' (1 syllable) => The result will show one-syllabled word list (randomly chosen from cmu dictionary)_
#
# * We'll then create an audio file reading the rhyming wordlist.

# %%
#@markdown # ✏️ <font color = 'red'> **Student's activity 8** ⤵️ 
#@markdown 11 .👀 **Step 2:** 	🚩 Find rhyming words with ____: Note that I find some errors (10% of error rate in pronouncing words.)

print("Write a word to search rhyming words:")
rhyme_with = input()
word = rhyme_with

phones = pronouncing.phones_for_word(word)
syll_count = pronouncing.syllable_count(phones[0])

print("Okay, I'm searching for rhyming words with %s."%word)

result = pronouncing.rhymes(word)

print('How many rhyming words to search? (1~20')
n_words = input()
n_words = int(n_words)

# Among the result, select words with same syllable count

wlist = []
throw = []

def syllcount(x):
  phones = pronouncing.phones_for_word(x)
  n = pronouncing.syllable_count(phones[0])
  return n

for w in result:
  if syllcount(w) == syll_count:
    wlist.append(w)
  else:
    throw.append(w)

# random sample
import random
from random import shuffle

b = random.sample(wlist, n_words)

temp = b[:n_words]

wlist = '. '.join(temp)
intro = "These words rhyme with " + str(rhyme_with) + ". " + "Are you ready to listen?"

wlist = intro + wlist
print("Rhyming words: %s"%wlist)

#@markdown tts() function should be defined above [1]:
tts(wlist)
# Out:
# Write a word to search rhyming words:
# beat
# Okay, I'm searching for rhyming words with beat.
# How many rhyming words to search? (1~20
# 5
# Rhyming words: These words rhyme with beat. Are you ready to listen?skeet. streett. meet. breit. cliett
# Play language accent: en
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## **[3]English vowels to learn (Sample 4 vowels with representative simple words)**
#
# piece vs. piss
# who'd vs. hood

# %%
#@markdown # ✏️ <font color = 'red'> **Student's activity 9** ⤵️ 
#@markdown 12.👀 Target words to learn pronunciation:

vowel_in_word = "i_piece" #@param ["i_piece", "I_skin", "u_root", "U_good"]

ivowel = ["piece", "need","meet", "seat","see","bean","mean","lead","believe","meal"]
iv = ".  ".join(ivowel)
uvowel = ["root","mood","who","rule","afternoon","food","suit","balloon","cool","moon"]
uv = ".  ".join(uvowel)
Ivowel = ["skin","fit","bit","hit","sit","little","silk","milk","hill","ill"]
Iv = ".  ".join(Ivowel)
Uvowel = ["good","book","cook","would","could","should","wood","wolf","woman","put"]
Uv = ".  ".join(Uvowel)
vlist = {'i_piece': iv, 'I_skin': Iv, 'u_root': uv, 'U_good': Uv}

text_to_say1 = vlist.get(vowel_in_word)
intro = "I'll be saying ten words that share the same vowel. Listen carefully. "

text_to_say = intro + text_to_say1
print(vlist[vowel_in_word])
tts(text_to_say)
# Out:
# piece.  need.  meet.  seat.  see.  bean.  mean.  lead.  believe.  meal
# Play language accent: en
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown # ✏️ <font color = 'red'> **Student's activity 10** ⤵️ 
#@markdown 13.👀 Two vowel in comparison: write two words to compare (e.g., hill, heal)

twowords = input()
tts(twowords)
# Out:
# beat, bit
# Play language accent: en
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##**[4] Larning English vowels with rhyming words**
# ### **3.1 9 Monophthongs (simple vowels) and 5 diphthong vowels in English**
#
# * Note: Vowel inventories may differ from one dialect to another. We follow abstractly defined General American English vowel system. (See Ladefoged & Johnson (2017), A course in Phonetics.

# %% [markdown]
# ### English monophthong vowels: 10 vowels (**The schwa vowel** is excluded here)
#
# ![](https://github.com/MK316/workshop22/raw/main/img/englishvowels1.png)

# %%
#@markdown **Step 1:** Install {pronouncing}
# %%capture
# !pip install pronouncing
# !pip install gTTS

from gtts import gTTS
from IPython.display import Audio
import pronouncing

# %%
#@markdown **Step2:** 🚩 Vowels to learn:

#@markdown 🐳 Note: 'taught' has the same vowel with 'top' in the speaker's dialect.
Target_vowel_as_in = "bin" #@param ["bean","bin","Ben","ban","mood","would","taught","nod", "mud","go","how","bay","bye","boy"]

word = Target_vowel_as_in

#@markdown 🐳 Number of syllable: 1~3 (Select "ignore" for not using this option.)
number_of_syllables = "1" #@param ["1","2","3","4","ignore"]

# phones = pronouncing.phones_for_word(word)
# syll_count = pronouncing.syllable_count(phones[0])

result = pronouncing.rhymes(word)

# syllable number counting as function
def syllcount(x):
  phones = pronouncing.phones_for_word(x)
  n = pronouncing.syllable_count(phones[0])
  return n

wlist = []

# (syllcount(w) == 1 or 2)
for w in result:
  if (number_of_syllables == "ignore"):
    wlist.append(w)
  elif (int(number_of_syllables) == syllcount(w)) and (len(w) > 1):
    wlist.append(w)
  else:
    throw.append(w)

print("Rhyming words: %d"%len(wlist))

How_many_words_to_show = "5" #@param = ["5","10","15","20","30"]
n_words = int(How_many_words_to_show)
# random sample
import random
from random import shuffle

if len(wlist) > n_words:
  b = random.sample(wlist, n_words)
  temp = b[:n_words]
else:
  temp = wlist


# wordlist as dataframe to display
import pandas as pd
dft = pd.DataFrame()
dft['Words'] = temp

wlist = '. '.join(temp)
intro = "These are randomly chosen " + str(n_words) + " words that rhyme with " + str(word) + ". " + "Are you ready to listen? "

wlist = intro + wlist
print("Rhyming words: \n %s"%wlist)
print("*** Target vowel in '%s'"%word)
print(dft)

tts(wlist)
# Out:
# Rhyming words: 83
# Rhyming words:
#  These are randomly chosen 5 words that rhyme with bin. Are you ready to listen? gwin. gwynne. quin. guinn. guin
# *** Target vowel in 'bin'
#     Words
# 0    gwin
# 1  gwynne
# 2    quin
# 3   guinn
# 4    guin
# Play language accent: en
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Do you want to see the whole rhyming words?
print(result)
# Out:
# ['adin', 'akin', 'allin', 'allphin', 'alpin', 'askin', 'aslin', 'astin', 'aswin', 'atkin', 'been', 'begin', 'berlin', 'bihn', 'binn', 'blinn', 'boleyn', 'bongjin', 'brin', 'brinn', 'bryn', 'chagrin', 'chang-hsin', 'chin', 'chinh', 'chinn', 'dechine', 'din', 'dinh', 'eldwin', 'elkin', 'emlyn', 'eskin', 'fin', 'finn', 'finne', 'flinn', 'flynn', 'gin', 'ginn', 'glavine', 'glyn', 'glynn', 'grin', 'guin', 'guinn', 'gwin', 'gwinn', 'gwyn', 'gwynn', 'gwynne', 'gyn', 'herein', 'hinn', 'in', 'in.', 'inn', 'itkin', 'jin', 'kaylynn', 'kihn', 'kin', 'kinn', 'kinne', 'knin', 'knin', 'kyoung-min', 'laminne', 'levin', 'lin', 'linh', 'linn', 'linne', 'lwin', 'lyn', 'lynn', 'lynne', 'mcginn', 'mcglinn', 'mcglynn', 'mcguinn', 'mclin', 'mclinn', 'mcminn', 'mcquinn', 'mihn', 'min', 'minh', "o'flynn", "o'guinn", "o'quinn", 'oflynn', 'oguinn', 'pin', 'pinn', 'prynne', 'qian', 'qin', 'quin', 'quinn', 'rhin', 'rihn', 'rinn', 'rinne', 'schwinn', 'shin', 'shinn', 'sin', 'sinn', 'skin', 'spin', 'syn', 'therein', 'thin', 'tin', 'trinh', 'twin', 'vanryn', 'verduin', 'vin', 'violin', 'when', 'when', 'wherein', 'wherein', 'win', 'win-win', 'winn', 'winne', 'within', 'within', 'wynn', 'wynne', 'yalin', 'yan-bin', 'yin', 'zinn', 'zlin']

# %%
#@markdown 🐳 Find stress pattern: 
wordstress = input()
pronouncing.stresses(pronouncing.phones_for_word(wordstress)[0])
# Out:
# combination
# '2010'
